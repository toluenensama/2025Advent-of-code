# %%
# %%bash
# set -euo pipefail
#
# MAMBA_ROOT="$HOME/mamba"
# MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
# if [ ! -x "$MAMBA_BIN" ]; then
#   mkdir -p "$MAMBA_ROOT"
#   curl -Ls https://micro.mamba.pm/api/micromamba/linux-64/latest | tar -xvj -C "$MAMBA_ROOT" bin/micromamba >/dev/null
# fi
#
# "$MAMBA_BIN" create -y -r "$MAMBA_ROOT" -n psi4 -c conda-forge psi4 python=3.12 >/dev/null

# %%
# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
# %%bash
set -euo pipefail
MAMBA_ROOT="$HOME/mamba"
MAMBA_BIN="$MAMBA_ROOT/bin/micromamba"
cat > psi4.in <<'EOF'
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>

molecule {

  O
  O 1 ROO2
  H 1 RHO3 2 AHOO3
  H 2 RHO4 1 AHOO4 3 DHOOH4

  ROO2 = 1.2
  RHO3 = 1.0
  RHO4 = 1.0
  AHOO3 = 109.5
  AHOO4 = 109.5
  DHOOH4 = 175
}

set {
  basis aug-cc-pVDZ
  reference rhf
}

optimize("MP2")
# Your input file should go in this middle section
# Write this as a classic-style Psi4 input file (not a Python script)



# <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# STUDENTS SHOULD IGNORE THESE LINES
EOF
"$MAMBA_BIN" run -r "$MAMBA_ROOT" -n psi4 psi4 psi4.in psi4.out
cat psi4.out
# >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
# Out:
# Optimizer: Optimization complete!
#
#     -----------------------------------------------------------------------
#           Psi4: An Open-Source Ab Initio Electronic Structure Package
#                                Psi4 1.10 release
#
#                          Git: Rev {} zzzzzzz
#
#
#     D. G. A. Smith, L. A. Burns, A. C. Simmonett, R. M. Parrish,
#     M. C. Schieber, R. Galvelis, P. Kraus, H. Kruse, R. Di Remigio,
#     A. Alenaizan, A. M. James, S. Lehtola, J. P. Misiewicz, M. Scheurer,
#     R. A. Shaw, J. B. Schriber, Y. Xie, Z. L. Glick, D. A. Sirianni,
#     J. S. O'Brien, J. M. Waldrop, A. Kumar, E. G. Hohenstein,
#     B. P. Pritchard, B. R. Brooks, H. F. Schaefer III, A. Yu. Sokolov,
#     K. Patkowski, A. E. DePrince III, U. Bozkaya, R. A. King,
#     F. A. Evangelista, J. M. Turney, T. D. Crawford, C. D. Sherrill,
#     J. Chem. Phys. 152(18) 184108 (2020). https://doi.org/10.1063/5.0006002
#
#                             Additional Code Authors
#     E. T. Seidl, C. L. Janssen, E. F. Valeev, M. L. Leininger,
#     J. F. Gonthier, R. M. Richard, H. R. McAlexander, M. Saitow, X. Wang,
#     P. Verma, M. H. Lechner, A. Jiang, S. Behnle, A. G. Heide,
#     M. F. Herbst, D. L. Poole, T. Győri, E. C. Mitchell, J. P. Pederson,
#     and A. M. Wallace
#
#              Previous Authors, Complete List of Code Contributors,
#                        and Citations for Specific Modules
#     https://github.com/psi4/psi4/blob/master/codemeta.json
#     https://github.com/psi4/psi4/graphs/contributors
#     https://psicode.org/psi4manual/master/introduction.html#citing-psifour
#
#     -----------------------------------------------------------------------
#
#
#     Psi4 started on: Tuesday, 19 May 2026 11:26AM
#
#     Process ID: 27560
#     Host:       4c6e94dff8de
#     PSIDATADIR: /root/mamba/envs/psi4/share/psi4
#     Memory:     500.0 MiB
#     Threads:    1
#     Addons:     a̶d̶c̶c̶, a̶m̶b̶i̶t̶, b̶s̶e̶, c̶c̶t̶3̶, c̶f̶o̶u̶r̶, c̶h̶e̶m̶p̶s̶2̶, c̶p̶p̶e̶, d̶d̶x̶,
#                 d̶f̶t̶d̶3̶, d̶f̶t̶d̶4̶, dkh, ecpint, einsums, f̶o̶r̶t̶e̶, g̶a̶u̶x̶c̶, g̶c̶p̶,
#                 g̶d̶m̶a̶, g̶e̶o̶m̶e̶t̶r̶i̶c̶, g̶p̶u̶_̶d̶f̶c̶c̶, i̶n̶t̶e̶g̶r̶a̶t̶o̶r̶x̶x̶,
#                 i̶p̶i̶, l̶i̶b̶e̶f̶p̶, m̶d̶i̶, m̶p̶2̶d̶, m̶r̶c̶c̶, ooo,
#                 o̶p̶e̶n̶f̶e̶r̶m̶i̶o̶n̶p̶s̶i̶4̶, pcmsolver, p̶s̶i̶4̶f̶o̶c̶k̶c̶i̶, p̶s̶i̶x̶a̶s̶,
#                 r̶e̶s̶p̶, s̶i̶m̶i̶n̶t̶, s̶n̶s̶m̶p̶2̶, v̶2̶r̶d̶m̶_̶c̶a̶s̶s̶c̶f̶
#
#   ==> Input File <==
#
# --------------------------------------------------------------------------
# # >>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>
#
# molecule {
#
#   O
#   O 1 ROO2
#   H 1 RHO3 2 AHOO3
#   H 2 RHO4 1 AHOO4 3 DHOOH4
#
#   ROO2 = 1.2
#   RHO3 = 1.0
#   RHO4 = 1.0
#   AHOO3 = 109.5
#   AHOO4 = 109.5
#   DHOOH4 = 175
# }
#
# set {
#   basis aug-cc-pVDZ
#   reference rhf
# }
#
# optimize("MP2")
# # Your input file should go in this middle section
# # Write this as a classic-style Psi4 input file (not a Python script)
#
#
#
# # <<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# # STUDENTS SHOULD IGNORE THESE LINES
# --------------------------------------------------------------------------
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:30 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.600000000000     0.002437206622    15.994914619570
#          O            0.000000000000    -0.600000000000     0.002437206622    15.994914619570
#          H           -0.941744305265     0.933806859234    -0.038680237724     1.007825032230
#          H            0.941744305265    -0.933806859234    -0.038680237724     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =     11.06487  B =      1.24461  C =      1.11924 [cm^-1]
#   Rotational constants: A = 331716.58613  B =  37312.47463  C =  33554.09316 [MHz]
#   Nuclear repulsion =   41.592097424201953
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is SAD.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 1.2106448129E-03.
#   Reciprocal condition number of the overlap matrix is 2.2511041069E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Superposition of Atomic Densities via on-the-fly atomic UHF (no occupation information).
#
#    -------------------------
#     Irrep   Nso     Nmo
#    -------------------------
#      A         32      32
#      B         32      32
#    -------------------------
#     Total      64      64
#    -------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter SAD:  -152.16716468819172   -1.52167e+02   0.00000e+00
#    @DF-RHF iter   1:  -147.67980892580491    4.48736e+00   4.21674e-02 ADIIS/DIIS
#    @DF-RHF iter   2:  -149.62335080454420   -1.94354e+00   3.74474e-02 ADIIS/DIIS
#    @DF-RHF iter   3:  -150.73188323996970   -1.10853e+00   4.13515e-03 ADIIS/DIIS
#    @DF-RHF iter   4:  -150.75289437891482   -2.10111e-02   6.83076e-04 ADIIS/DIIS
#    @DF-RHF iter   5:  -150.75386762272885   -9.73244e-04   1.59451e-04 ADIIS/DIIS
#    @DF-RHF iter   6:  -150.75391779663357   -5.01739e-05   2.78986e-05 DIIS
#    @DF-RHF iter   7:  -150.75391967593282   -1.87930e-06   8.23308e-06 DIIS
#    @DF-RHF iter   8:  -150.75391979268790   -1.16755e-07   1.76698e-06 DIIS
#    @DF-RHF iter   9:  -150.75391979993842   -7.25052e-09   3.18136e-07 DIIS
#    @DF-RHF iter  10:  -150.75391980039248   -4.54065e-10   1.14618e-07 DIIS
#    @DF-RHF iter  11:  -150.75391980044043   -4.79474e-11   1.80142e-08 DIIS
#    @DF-RHF iter  12:  -150.75391980044174   -1.30740e-12   4.03055e-09 DIIS
#    @DF-RHF iter  13:  -150.75391980044191   -1.70530e-13   1.11975e-09 DIIS
#    @DF-RHF iter  14:  -150.75391980044174    1.70530e-13   2.01541e-10 DIIS
#    @DF-RHF iter  15:  -150.75391980044193   -1.98952e-13   4.66335e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.613095     1B    -20.612415     2A     -1.621481
#        2B     -1.152671     3A     -0.760142     3B     -0.759885
#        4A     -0.695233     5A     -0.493067     4B     -0.388412
#
#     Virtual:
#
#        6A      0.042470     5B      0.047525     6B      0.134642
#        7B      0.190253     7A      0.194074     8A      0.203338
#        9A      0.218549    10A      0.241253     8B      0.246112
#       11A      0.334892     9B      0.343507    10B      0.369845
#       11B      0.425979    12B      0.431178    12A      0.460579
#       13A      0.527308    13B      0.575204    14A      0.644936
#       14B      0.646595    15B      0.868042    15A      0.899743
#       16B      1.033309    16A      1.074044    17A      1.087209
#       17B      1.156740    18A      1.219600    19A      1.246300
#       18B      1.322140    19B      1.334703    20A      1.417448
#       20B      1.474839    21A      1.500568    21B      1.625298
#       22B      1.728394    22A      1.745457    23B      2.047154
#       23A      2.121336    24B      2.198907    25B      2.340277
#       24A      2.387663    25A      2.489466    26A      2.605189
#       26B      2.792637    27A      2.872558    28A      3.198882
#       27B      3.382007    29A      3.446303    28B      3.592319
#       30A      3.711595    31A      3.761201    29B      3.784362
#       30B      4.105182    31B      4.231602    32A      4.252755
#       32B      4.445322
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.75391980044193
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             41.5920974242019525
#     One-Electron Energy =                -290.4992317932552623
#     Two-Electron Energy =                  98.1532145686113893
#     Total Energy =                       -150.7539198004419347
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0134193           -0.0724997           -0.0590803
#  Magnitude           :                                                    0.0590803
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:32 2026
# Module time:
# 	user time   =       1.38 seconds =       0.02 minutes
# 	system time =       0.22 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
# Total time:
# 	user time   =       1.38 seconds =       0.02 minutes
# 	system time =       0.22 seconds =       0.00 minutes
# 	total time  =          2 seconds =       0.03 minutes
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:32 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.600000000000     0.002437206622    15.994914619570
#          O            0.000000000000    -0.600000000000     0.002437206622    15.994914619570
#          H           -0.941744305265     0.933806859234    -0.038680237724     1.007825032230
#          H            0.941744305265    -0.933806859234    -0.038680237724     1.007825032230
#
#   Nuclear repulsion =   41.592097424201953
#   Reference energy  = -150.753919800441935
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   1.096E-01
#   CGR           2          0          1   2.196E-02
#   CGR           3          0          1   2.909E-03
#   CGR           4          0          1   6.965E-04
#   CGR           5          0          1   2.060E-04
#   CGR           6          0          1   3.021E-05
#   CGR           7          0          1   8.298E-06
#   CGR           8          0          1   1.814E-06
#   CGR           9          1          0   3.090E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7539198004419347 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1063600609384685 [Eh]
# 	 Opposite-Spin Energy      =      -0.2971098078402806 [Eh]
# 	 Correlation Energy        =      -0.4034698687787491 [Eh]
# 	 Total Energy              =    -151.1573896692206915 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0354533536461562 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3565317694083368 [Eh]
# 	 SCS Correlation Energy    =      -0.3919851230544929 [Eh]
# 	 SCS Total Energy          =    -151.1459049234964311 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.013705998885    -0.315021448352     0.000038708193
#        2       -0.013705998885     0.315021448352     0.000038708193
#        3       -0.027411597917     0.018448260519    -0.000038708193
#        4        0.027411597917    -0.018448260519    -0.000038708193
#
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:33 2026
# Module time:
# 	user time   =       0.70 seconds =       0.01 minutes
# 	system time =       0.07 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       2.08 seconds =       0.03 minutes
# 	system time =       0.29 seconds =       0.00 minutes
# 	total time  =          3 seconds =       0.05 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.13383568  0.00460565
# 	       8.000000            15.994915          0.00000000 -1.13383568  0.00460565
# 	       1.000000             1.007825         -1.77963882  1.76463922 -0.07309506
# 	       1.000000             1.007825          1.77963882 -1.76463922 -0.07309506
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.267671           1.200000
# 	 R(1,3)           =         1.889726           1.000000
# 	 R(2,4)           =         1.889726           1.000000
# 	 B(1,2,4)         =         1.911136         109.500000
# 	 B(2,1,3)         =         1.911136         109.500000
# 	 D(3,1,2,4)       =         3.054326         175.000000
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.20000        2.44338        0.13868       1.33868
# 	               R(1,3)       1.00000       -0.26343       -0.03020       0.96980
# 	               R(2,4)       1.00000       -0.26343       -0.03020       0.96980
# 	             B(1,2,4)     109.50000       -0.00119       -3.66887     105.83113
# 	             B(2,1,3)     109.50000       -0.00119       -3.66887     105.83113
# 	           D(3,1,2,4)     175.00000       -0.00016       -1.16245     173.83755
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------~
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp   ~
# 	----------------------------------------------------------------------------------------------~
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o~
# 	----------------------------------------------------------------------------------------------~
# 	     1    -151.15738967   -1.51e+02      2.97e-01      1.23e-01 o    2.62e-01      1.18e-01 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O  -0.0029293037   0.6693352111   0.0069540547
# 	    O   0.0029293037  -0.6693352111   0.0069540547
# 	    H  -0.9357460746   0.9298200070  -0.0431970858
# 	    H   0.9357460746  -0.9298200070  -0.0431970858
#
#
#     Structure for next step:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1        ROO2
#     H             1        RHO3      2       AHOO3
#     H             2        RHO4      1       AHOO4      3      DHOOH4
#
#     AHOO3     =  105.8311280267
#     AHOO4     =  105.8311280267
#     DHOOH4    =  173.8375503381
#     RHO3      =    0.9698013167
#     RHO4      =    0.9698013167
#     ROO2      =    1.3386832421
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:33 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.669341621042     0.002972672389    15.994914619570
#          O            0.000000000000    -0.669341621042     0.002972672389    15.994914619570
#          H           -0.931667853307     0.933906297566    -0.047178468019     1.007825032230
#          H            0.931667853307    -0.933906297566    -0.047178468019     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =     10.92527  B =      1.03382  C =      0.94495 [cm^-1]
#   Rotational constants: A = 327531.39438  B =  30993.10399  C =  28329.00440 [MHz]
#   Nuclear repulsion =   38.794452231187655
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.27560.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.1454297413E-03.
#   Reciprocal condition number of the overlap matrix is 4.0071587131E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -150.89545692502332   -1.50895e+02   1.28062e-02
#    @DF-RHF iter   1:  -150.79204747943550    1.03409e-01   2.47398e-03 ADIIS/DIIS
#    @DF-RHF iter   2:  -150.79662408462704   -4.57661e-03   1.26442e-03 ADIIS/DIIS
#    @DF-RHF iter   3:  -150.79772872075569   -1.10464e-03   1.31491e-04 ADIIS/DIIS
#    @DF-RHF iter   4:  -150.79776008035856   -3.13596e-05   4.12981e-05 DIIS
#    @DF-RHF iter   5:  -150.79776326797008   -3.18761e-06   8.87286e-06 DIIS
#    @DF-RHF iter   6:  -150.79776346871407   -2.00744e-07   1.49344e-06 DIIS
#    @DF-RHF iter   7:  -150.79776347463604   -5.92198e-09   2.06364e-07 DIIS
#    @DF-RHF iter   8:  -150.79776347475303   -1.16984e-10   4.62499e-08 DIIS
#    @DF-RHF iter   9:  -150.79776347476079   -7.75913e-12   1.64879e-08 DIIS
#    @DF-RHF iter  10:  -150.79776347476229   -1.50635e-12   4.12233e-09 DIIS
#    @DF-RHF iter  11:  -150.79776347476218    1.13687e-13   1.16923e-09 DIIS
#    @DF-RHF iter  12:  -150.79776347476238   -1.98952e-13   3.94172e-10 DIIS
#    @DF-RHF iter  13:  -150.79776347476226    1.13687e-13   7.28148e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.626649     1B    -20.626253     2A     -1.529405
#        2B     -1.196297     3B     -0.737513     3A     -0.719069
#        4A     -0.652028     5A     -0.527623     4B     -0.432432
#
#     Virtual:
#
#        6A      0.042148     5B      0.048424     6B      0.133976
#        7B      0.194081     7A      0.196112     8A      0.202464
#        9A      0.216782    10A      0.240943     8B      0.243813
#       11A      0.335060     9B      0.346394    10B      0.369851
#       11B      0.375198    12B      0.427228    12A      0.464186
#       13B      0.496741    13A      0.535569    14B      0.633345
#       14A      0.648849    15B      0.874294    15A      0.901345
#       16A      1.043869    16B      1.045904    17A      1.092985
#       17B      1.125528    18A      1.217607    19A      1.247882
#       18B      1.304644    19B      1.316776    20A      1.413747
#       21A      1.460099    20B      1.463592    21B      1.591201
#       22B      1.723291    22A      1.765520    23B      2.062038
#       23A      2.114159    24B      2.169662    24A      2.371984
#       25B      2.407212    25A      2.432140    26A      2.580147
#       26B      2.794977    27A      2.853490    28A      3.337407
#       29A      3.346466    27B      3.483391    28B      3.642863
#       30A      3.682375    29B      3.693604    31A      3.812531
#       30B      3.905227    32A      4.110033    31B      4.237796
#       32B      4.401757
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.79776347476226
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             38.7944522311876554
#     One-Electron Energy =                -285.0898922437155534
#     Two-Electron Energy =                  95.4976765377656278
#     Total Energy =                       -150.7977634747622915
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.0155766           -0.0884282           -0.0728516
#  Magnitude           :                                                    0.0728516
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:34 2026
# Module time:
# 	user time   =       0.43 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =       2.58 seconds =       0.04 minutes
# 	system time =       0.31 seconds =       0.01 minutes
# 	total time  =          4 seconds =       0.07 minutes
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:34 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.669341621042     0.002972672389    15.994914619570
#          O            0.000000000000    -0.669341621042     0.002972672389    15.994914619570
#          H           -0.931667853307     0.933906297566    -0.047178468019     1.007825032230
#          H            0.931667853307    -0.933906297566    -0.047178468019     1.007825032230
#
#   Nuclear repulsion =   38.794452231187648
#   Reference energy  = -150.797763474762263
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   9.306E-02
#   CGR           2          0          1   1.929E-02
#   CGR           3          0          1   2.419E-03
#   CGR           4          0          1   4.404E-04
#   CGR           5          0          1   1.455E-04
#   CGR           6          0          1   4.194E-05
#   CGR           7          0          1   1.212E-05
#   CGR           8          0          1   2.614E-06
#   CGR           9          1          0   4.294E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7977634747622631 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1073389441274743 [Eh]
# 	 Opposite-Spin Energy      =      -0.3032330917008478 [Eh]
# 	 Correlation Energy        =      -0.4105720358283221 [Eh]
# 	 Total Energy              =    -151.2083355105905866 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0357796480424914 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3638797100410174 [Eh]
# 	 SCS Correlation Energy    =      -0.3996593580835088 [Eh]
# 	 SCS Total Energy          =    -151.1974228328457741 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1       -0.014032369686    -0.096994148166    -0.000664390480
#        2        0.014032369686     0.096994148166    -0.000664390480
#        3       -0.001099681116     0.011183661645     0.000664390480
#        4        0.001099681116    -0.011183661645     0.000664390480
#
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:34 2026
# Module time:
# 	user time   =       0.68 seconds =       0.01 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          0 seconds =       0.00 minutes
# Total time:
# 	user time   =       3.26 seconds =       0.05 minutes
# 	system time =       0.35 seconds =       0.01 minutes
# 	total time  =          4 seconds =       0.07 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.26487235  0.00561754
# 	       8.000000            15.994915          0.00000000 -1.26487235  0.00561754
# 	       1.000000             1.007825         -1.76059708  1.76482713 -0.08915438
# 	       1.000000             1.007825          1.76059708 -1.76482713 -0.08915438
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.529745           1.338683
# 	 R(1,3)           =         1.832659           0.969801
# 	 R(2,4)           =         1.832659           0.969801
# 	 B(1,2,4)         =         1.847102         105.831128
# 	 B(2,1,3)         =         1.847102         105.831128
# 	 D(3,1,2,4)       =         3.034038         173.837550
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.33868        0.70697        0.06291       1.40159
# 	               R(1,3)       0.96980       -0.03356       -0.00550       0.96430
# 	               R(2,4)       0.96980       -0.03356       -0.00550       0.96430
# 	             B(1,2,4)     105.83113       -0.00146       -8.32906      97.50207
# 	             B(2,1,3)     105.83113       -0.00146       -8.32906      97.50207
# 	           D(3,1,2,4)     173.83755       -0.00010       -1.87370     171.96385
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	     2    -151.20833551   -5.09e-02      8.58e-02      3.68e-02 o    1.45e-01      9.81e-02 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O   0.0395895533   0.6996780127   0.0113927219
# 	    O  -0.0395895533  -0.6996780127   0.0113927219
# 	    H  -0.9054705255   0.8792542015  -0.0555985175
# 	    H   0.9054705255  -0.8792542015  -0.0555985175
#
#
#     Structure for next step:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1        ROO2
#     H             1        RHO3      2       AHOO3
#     H             2        RHO4      1       AHOO4      3      DHOOH4
#
#     AHOO3     =   97.5020702097
#     AHOO4     =   97.5020702097
#     DHOOH4    =  171.9638482616
#     RHO3      =    0.9642997388
#     RHO4      =    0.9642997388
#     ROO2      =    1.4015943124
#
#
# Scratch directory: /tmp/
# gradient() will perform analytic gradient computation.
#     SCF Algorithm Type (re)set to DF.
#    => Libint2 <=
#
#     Primary   basis highest AM E, G, H:  7, 6, 3
#     Auxiliary basis highest AM E, G, H:  7, 7, 4
#     Onebody   basis highest AM E, G, H:  -, -, -
#     Solid Harmonics ordering:            Gaussian
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:34 2026
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#
#          ---------------------------------------------------------
#                                    SCF
#                by Justin Turney, Rob Parrish, Andy Simmonett
#                           and Daniel G. A. Smith
#                               RHF Reference
#                         1 Threads,    500 MiB Core
#          ---------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.700797156199     0.003970857012    15.994914619570
#          O            0.000000000000    -0.700797156199     0.003970857012    15.994914619570
#          H           -0.953695506583     0.826698073162    -0.063020382347     1.007825032230
#          H            0.953695506583    -0.826698073162    -0.063020382347     1.007825032230
#
#   Running in c2 symmetry.
#
#   Rotational constants: A =     10.04613  B =      0.97665  C =      0.89092 [cm^-1]
#   Rotational constants: A = 301175.45653  B =  29279.35028  C =  26709.10886 [MHz]
#   Nuclear repulsion =   37.851905154101310
#
#   Charge       = 0
#   Multiplicity = 1
#   Electrons    = 18
#   Nalpha       = 9
#   Nbeta        = 9
#
#   ==> Algorithm <==
#
#   SCF Algorithm Type is DF.
#   DIIS enabled.
#   MOM disabled.
#   Fractional occupation disabled.
#   Guess Type is READ.
#   Energy threshold   = 1.00e-10
#   Density threshold  = 1.00e-10
#   Integral threshold = 1.00e-12
#
#   ==> Primary Basis <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: JKFIT
#     Keyword: DF_BASIS_SCF
#     atoms 1-2 entry O          line   270 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#     atoms 3-4 entry H          line    70 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-jkfit.gbs
#
#    => Loading Basis Set <=
#
#     Name: AUG-CC-PVDZ
#     Role: ORBITAL
#     Keyword: BASIS
#     atoms 1-2 entry O          line   254 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#     atoms 3-4 entry H          line    40 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz.gbs
#
#   Reading orbitals from file /tmp/psi4.default.27560.180.npy, no projection.
#
#   ==> Integral Setup <==
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   Minimum eigenvalue in the overlap matrix is 2.1198546051E-03.
#   Reciprocal condition number of the overlap matrix is 4.0886905374E-04.
#     Using symmetric orthogonalization.
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -150.79245348609072   -1.50792e+02   4.91366e-03
#    @DF-RHF iter   1:  -150.80015931522718   -7.70583e-03   6.71094e-04 ADIIS/DIIS
# ...
#
#   ==> Pre-Iterations <==
#
#   SCF Guess: Orbitals guess was supplied from a previous computation.
#
#    -------------------------------------------------------
#     Irrep   Nso     Nmo     Nalpha   Nbeta   Ndocc  Nsocc
#    -------------------------------------------------------
#      A         32      32       5       5       5       0
#      B         32      32       4       4       4       0
#    -------------------------------------------------------
#     Total      64      64       9       9       9       0
#    -------------------------------------------------------
#
#   ==> Iterations <==
#
#                            Total Energy        Delta E     RMS |[F,P]|
#
#    @DF-RHF iter   0:  -150.79933712708123   -1.50799e+02   8.96876e-05
#    @DF-RHF iter   1:  -150.79942427665642   -8.71496e-05   1.47896e-05 DIIS
#    @DF-RHF iter   2:  -150.79942448648066   -2.09824e-07   5.87016e-06 DIIS
#    @DF-RHF iter   3:  -150.79942451981520   -3.33345e-08   1.81698e-06 DIIS
#    @DF-RHF iter   4:  -150.79942452782214   -8.00694e-09   6.78278e-07 DIIS
#    @DF-RHF iter   5:  -150.79942452933932   -1.51718e-09   2.21810e-07 DIIS
#    @DF-RHF iter   6:  -150.79942452956033   -2.21007e-10   6.73244e-08 DIIS
#    @DF-RHF iter   7:  -150.79942452958545   -2.51248e-11   2.60736e-08 DIIS
#    @DF-RHF iter   8:  -150.79942452958969   -4.23483e-12   4.71482e-09 DIIS
#    @DF-RHF iter   9:  -150.79942452958983   -1.42109e-13   6.35490e-10 DIIS
#    @DF-RHF iter  10:  -150.79942452958977    5.68434e-14   1.60143e-10 DIIS
#    @DF-RHF iter  11:  -150.79942452958983   -5.68434e-14   3.73826e-11 DIIS
#   Energy and wave function converged.
#
#
#   ==> Post-Iterations <==
#
#     Orbital Energies [Eh]
#     ---------------------
#
#     Doubly Occupied:
#
#        1A    -20.644808     1B    -20.644538     2A     -1.473424
#        2B     -1.221665     3B     -0.711209     3A     -0.709711
#        4A     -0.606705     5A     -0.522676     4B     -0.490522
#
#     Virtual:
#
#        6A      0.039081     5B      0.049623     6B      0.132319
#        7A      0.168649     7B      0.197953     8A      0.213768
#        9A      0.230446     8B      0.234101    10A      0.242350
#        9B      0.277971    10B      0.304775    11A      0.352109
#       11B      0.419637    12A      0.427265    12B      0.454813
#       13B      0.479151    13A      0.499563    14A      0.630818
#       14B      0.652828    15B      0.843132    15A      0.884694
#       16A      1.052085    17A      1.065936    16B      1.072423
#       17B      1.140924    18A      1.184286    18B      1.233227
#       19A      1.284716    19B      1.308353    20B      1.432363
#       20A      1.436863    21A      1.510257    21B      1.541818
#       22B      1.691902    22A      1.768336    23A      2.047180
#       23B      2.069011    24A      2.110730    24B      2.188167
#       25B      2.281127    25A      2.378304    26A      2.540754
#       26B      2.705354    27A      2.850733    28A      3.410362
#       27B      3.547322    29A      3.551180    28B      3.637932
#       30A      3.666620    29B      3.669927    30B      3.766012
#       31A      3.775132    31B      4.046244    32A      4.116470
#       32B      4.303356
#
#     Final Occupation by Irrep:
#               A     B
#     DOCC [     5,    4 ]
#     NA   [     5,    4 ]
#     NB   [     5,    4 ]
#
#   @DF-RHF Final Energy:  -150.79942452958983
#
#    => Energetics <=
#
#     Nuclear Repulsion Energy =             36.4696850176048883
#     One-Electron Energy =                -280.4877024002137205
#     Two-Electron Energy =                  93.2185928530190182
#     Total Energy =                       -150.7994245295898281
#
# Computation Completed
#
#
# Properties will be evaluated at   0.000000,   0.000000,   0.000000 [a0]
#
# Properties computed using the SCF density matrix
#
#
#  Multipole Moments:
#
#  ------------------------------------------------------------------------------------
#      Multipole            Electronic (a.u.)      Nuclear  (a.u.)        Total (a.u.)
#  ------------------------------------------------------------------------------------
#
#  L = 1.  Multiply by 2.5417464519 to convert [e a0] to [Debye]
#  Dipole X            :          0.0000000            0.0000000            0.0000000
#  Dipole Y            :          0.0000000            0.0000000            0.0000000
#  Dipole Z            :          0.1877475           -0.9303148           -0.7425673
#  Magnitude           :                                                    0.7425673
#
#  ------------------------------------------------------------------------------------
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:57 2026
# Module time:
# 	user time   =       0.61 seconds =       0.01 minutes
# 	system time =       0.02 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      24.65 seconds =       0.41 minutes
# 	system time =       1.20 seconds =       0.02 minutes
# 	total time  =         27 seconds =       0.45 minutes
#
# *** tstart() called on 4c6e94dff8de
# *** at Tue May 19 11:26:57 2026
#
#
#   //>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>>//
#   //               DFMP2               //
#   //<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<//
#
#    => Loading Basis Set <=
#
#     Name: (AUG-CC-PVDZ AUX)
#     Role: RIFIT
#     Keyword: DF_BASIS_MP2
#     atoms 1-2 entry O          line   204 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#     atoms 3-4 entry H          line    30 file /root/mamba/envs/psi4/share/psi4/basis/aug-cc-pvdz-ri.gbs
#
# 	 --------------------------------------------------------
# 	                          DF-MP2
# 	      2nd-Order Density-Fitted Moller-Plesset Theory
# 	              RMP2 Wavefunction,   1 Threads
#
# 	        Rob Parrish, Justin Turney, Andy Simmonett,
# 	           Ed Hohenstein, and C. David Sherrill
# 	 --------------------------------------------------------
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-RI
#     Number of shells: 62
#     Number of basis functions: 190
#     Number of Cartesian functions: 222
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	 --------------------------------------------------------
# 	                 NBF =    64, NAUX =   190
# 	 --------------------------------------------------------
# 	   CLASS    FOCC     OCC    AOCC    AVIR     VIR    FVIR
# 	   PAIRS       0       9       9      55      55       0
# 	 --------------------------------------------------------
#
#   DFHelper Memory: AOs need 0.008 GiB; user supplied 0.366 GiB.
#   SCF_SUBTYPE=INCORE selected. In-core MEM_DF algorithm will be used.
#   Using in-core AOs.
#
#
#          ------------------------------------------------------------
#                                      CPHF
#                                   Rob Parrish
#          ------------------------------------------------------------
#
#   ==> Geometry <==
#
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#        Center              X                  Y                   Z               Mass
#     ------------   -----------------  -----------------  -----------------  -----------------
#          O            0.000000000000     0.734939460419     0.031274207046    15.994914619570
#          O            0.000000000000    -0.734939460419     0.031274207046    15.994914619570
#          H           -0.800652549590     0.889044247616    -0.496344360878     1.007825032230
#          H            0.800652549590    -0.889044247616    -0.496344360878     1.007825032230
#
#   Nuclear repulsion =   36.469685017604888
#   Reference energy  = -150.799424529589828
#
#   ==> Basis Set <==
#
#   Basis Set: AUG-CC-PVDZ
#     Blend: AUG-CC-PVDZ
#     Number of shells: 28
#     Number of basis functions: 64
#     Number of Cartesian functions: 68
#     Spherical Harmonics?: true
#     Max angular momentum: 2
#
#   ==> CGRSolver (by Rob Parrish) <==
#
#    Number of roots    =         1
#    Preconditioning    =    JACOBI
#    Convergence cutoff =     1E-06
#    Maximum iterations =       100
#
#   ==> CPHFRHamiltonian (by Rob Parrish) <==
#
#   ==> MemDFJK: Density-Fitted J/K Matrices <==
#
#     J tasked:                   Yes
#     K tasked:                   Yes
#     wK tasked:                   No
#     OpenMP threads:               1
#     Memory [MiB]:               375
#     Algorithm:                 Core
#     Schwarz Cutoff:           1E-12
#     Mask sparsity (%):       0.0000
#     Fitting Condition:        1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
#   ==> CPHF Iterations <==
#
#   => Iterations <=
#
#              Iter  Converged  Remaining    Residual
#   CGR           1          0          1   8.044E-02
#   CGR           2          0          1   2.061E-02
#   CGR           3          0          1   4.551E-03
#   CGR           4          0          1   1.769E-03
#   CGR           5          0          1   6.428E-04
#   CGR           6          0          1   2.031E-04
#   CGR           7          0          1   3.232E-05
#   CGR           8          0          1   6.866E-06
#   CGR           9          0          1   1.433E-06
#   CGR          10          1          0   3.432E-07
#
#     CGRSolver converged.
#
#   ==> DFCorrGrad: Density-Fitted Correlated Gradients <==
#
#     OpenMP threads:              1
#     Integrals threads:           1
#     Memory [GiB]:            0.366
#     Schwarz Cutoff:          0E+00
#     Fitting Condition:       1E-10
#
#    => Auxiliary Basis Set <=
#
#   Basis Set: (AUG-CC-PVDZ AUX)
#     Blend: AUG-CC-PVDZ-JKFIT
#     Number of shells: 80
#     Number of basis functions: 236
#     Number of Cartesian functions: 272
#     Spherical Harmonics?: true
#     Max angular momentum: 3
#
# 	-----------------------------------------------------------
# 	 ==================> DF-MP2 Energies <====================
# 	-----------------------------------------------------------
# 	 Reference Energy          =    -150.7994245295898281 [Eh]
# 	 Singles Energy            =      -0.0000000000000000 [Eh]
# 	 Same-Spin Energy          =      -0.1098173462152975 [Eh]
# 	 Opposite-Spin Energy      =      -0.3134533916979630 [Eh]
# 	 Correlation Energy        =      -0.4232707379132605 [Eh]
# 	 Total Energy              =    -151.2226952675030986 [Eh]
# 	-----------------------------------------------------------
# 	 ================> DF-SCS-MP2 Energies <==================
# 	-----------------------------------------------------------
# 	 SCS Same-Spin Scale       =       0.3333333333333333 [-]
# 	 SCS Opposite-Spin Scale   =       1.2000000000000000 [-]
# 	 SCS Same-Spin Energy      =      -0.0366057820717658 [Eh]
# 	 SCS Opposite-Spin Energy  =      -0.3761440700375556 [Eh]
# 	 SCS Correlation Energy    =      -0.4127498521093215 [Eh]
# 	 SCS Total Energy          =    -151.2121743816991568 [Eh]
# 	-----------------------------------------------------------
#
#
#   -Total Gradient:
#      Atom            X                  Y                   Z
#     ------   -----------------  -----------------  -----------------
#        1        0.000077841028    -0.000136649159     0.000005149169
#        2       -0.000077841028     0.000136649159     0.000005149169
#        3       -0.000049159480    -0.000016857919    -0.000005149168
#        4        0.000049159480     0.000016857919    -0.000005149168
#
#
# *** tstop() called on 4c6e94dff8de at Tue May 19 11:26:58 2026
# Module time:
# 	user time   =       1.08 seconds =       0.02 minutes
# 	system time =       0.04 seconds =       0.00 minutes
# 	total time  =          1 seconds =       0.02 minutes
# Total time:
# 	user time   =      25.74 seconds =       0.43 minutes
# 	system time =       1.24 seconds =       0.02 minutes
# 	total time  =         28 seconds =       0.47 minutes
#
#     			-----------------------------------------
#
#     			 OPTKING 3.0: for geometry optimizations
#
#     			     By R.A. King, Bethel University
#
#     			        with contributions from
#
#     			    A.V. Copan, J. Cayton, A. Heide
#
#     			-----------------------------------------
#
#
# 	                            ===> Fragment 1 <==
#
# 	 Z (Atomic Numbers)          Masses                          Geom
# 	       8.000000            15.994915          0.00000000  1.38883430  0.05909969
# 	       8.000000            15.994915          0.00000000 -1.38883430  0.05909969
# 	       1.000000             1.007825         -1.51301404  1.68005014 -0.93795491
# 	       1.000000             1.007825          1.51301404 -1.68005014 -0.93795491
#
# 	 - Coordinate -           - BOHR/RAD -       - ANG/DEG -
# 	 R(1,2)           =         2.777669           1.469879
# 	 R(1,3)           =         1.835248           0.971172
# 	 R(2,4)           =         1.835248           0.971172
# 	 B(1,2,4)         =         1.730149          99.130244
# 	 B(2,1,3)         =         1.730149          99.130244
# 	 D(3,1,2,4)       =         1.976260         113.231379
#
#
# 	        --- Internal Coordinate Step in ANG or DEG, aJ/ANG or AJ/DEG ---
# 	-------------------------------------------------------------------------------
# 	           Coordinate      Previous         Force          Change          New
# 	           ----------      --------        ------          ------        ------
# 	               R(1,2)       1.46988        0.00126        0.00026       1.47014
# 	               R(1,3)       0.97117       -0.00033       -0.00003       0.97114
# 	               R(2,4)       0.97117       -0.00033       -0.00003       0.97114
# 	             B(1,2,4)      99.13024        0.00000        0.01074      99.14098
# 	             B(2,1,3)      99.13024        0.00000        0.01074      99.14098
# 	           D(3,1,2,4)     113.23138       -0.00000       -0.25984     112.97154
# 	-------------------------------------------------------------------------------
#
# 	                                 ==> Convergence Check <==
#
# 	Measures of convergence in internal coordinates in au.
#
# 	Criteria marked as inactive (o), active & met (*), and active & unmet ( ).
#
# 	----------------------------------------------------------------------------------------------
# 	   Step    Total Energy     Delta E     Max Force     RMS Force      Max Disp      RMS Disp
# 	----------------------------------------------------------------------------------------------
# 	  Convergence Criteria     1.00e-06 *    3.00e-04 *             o    1.20e-03 *             o
# 	----------------------------------------------------------------------------------------------
# 	    19    -151.22269527   -8.78e-07 *    1.54e-04 *    7.34e-05 o    4.54e-03      1.87e-03 o  ~
# 	----------------------------------------------------------------------------------------------
#
# Next Geometry in Ang
# 	Fragment 1 (Ang)
#
# 	    O  -0.0005048526   0.7350691135   0.0321647589
# 	    O   0.0005048526  -0.7350691135   0.0321647589
# 	    H  -0.8000148594   0.8887995742  -0.4972349127
# 	    H   0.8000148594  -0.8887995742  -0.4972349127
#
#
#     Final optimized geometry and variables:
#     Molecular point group: c2
#     Full point group: C2
#
#     Geometry (in Angstrom), charge = 0, multiplicity = 1:
#
#     O
#     O             1        ROO2
#     H             1        RHO3      2       AHOO3
#     H             2        RHO4      1       AHOO4      3      DHOOH4
#
#     AHOO3     =   99.1302444980
#     AHOO4     =   99.1302444980
#     DHOOH4    =  113.2313794983
#     RHO3      =    0.9711715316
#     RHO4      =    0.9711715316
#     ROO2      =    1.4698789208
#
#
#     Psi4 stopped on: Tuesday, 19 May 2026 11:26AM
#     Psi4 wall time for execution: 0:00:30.35
#
# *** Psi4 exiting successfully. Buy a developer a beer!
